# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

import sys
# Import the API key.
path_config = '../config/'
sys.path.append(path_config)
from config import weather_api_key

# %%
# create a set of random latitude and longtitude combinations
lats = np.random.uniform(low=-90.000, high=90.000,size=1500)
lngs = np.random.uniform(low=-180.000,high=180.000, size =1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# loop through all the cities in our list
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes
    if (i% 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # create endpoint url with each city
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | busselton
# Processing Record 2 of Set 13 | atuona
# Processing Record 3 of Set 13 | barbacoas
# Processing Record 4 of Set 13 | rikitea
# Processing Record 5 of Set 13 | vaini
# Processing Record 6 of Set 13 | qaanaaq
# Processing Record 7 of Set 13 | mirina
# City not found. Skipping...
# Processing Record 8 of Set 13 | tuktoyaktuk
# Processing Record 9 of Set 13 | kotka
# Processing Record 10 of Set 13 | bambous virieux
# Processing Record 11 of Set 13 | haines junction
# Processing Record 12 of Set 13 | saskylakh
# Processing Record 13 of Set 13 | saldanha
# Processing Record 14 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 13 | mandali
# Processing Record 16 of Set 13 | hobart
# Processing Record 17 of Set 13 | baherden
# Processing Record 18 of Set 13 | kailua
# Processing Record 19 of Set 13 | kaitangata
# Processing Record 20 of Set 13 | guerrero negro
# Processing Record 21 of Set 13 | arauca
# Processing Record 22 of Set 13 | dustlik
# Processing Record 23 of Set 13 | chokurdakh
# Processing Record 24 of Set 13 | thompson
# Processing Record 25 of Set 13 | hasaki
# Processing Record 26 of Set 13 | hervey bay
# Processing Record 27 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 13 | cape town
# Processing Record 29 of Set 13 | mount isa
# Processing Record 30 of Set 13 | chapaevsk
# Processing Record 31 of Set 13 | terrell
# Processing Record 32 of Set 13 | griffith
# Processing Record 33 of Set 13 | port alfred
# Processing Record 34 of Set 13 | new norfolk
# Processing Record 35 of Set 13 | tautira
# Processing Record 36 of Set 13 | sinnamary
# Processing Record 37 of Set 13 | clyde river
# Processing Record 38 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 13 | arraial do cabo
# Processing Record 40 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 13 | mataura
# Processing Record 42 of Set 13 | lavrentiya
# Processing Record 43 of Set 13 | kasongo-lunda
# Processing Record 44 of Set 13 | novobiryusinskiy
# Processing Record 45 of Set 13 | punta arenas
# Processing Record 46 of Set 13 | sorland
# Processing Record 47 of Set 13 | khatanga
# Processing Record 48 of Set 13 | saint-philippe
# Processing Record 49 of Set 13 | alofi
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | penzance
# Processing Record 2 of Set 14 | tasiilaq
# Processing Record 3 of Set 14 | albany
# Processing Record 4 of Set 14 | bykovo
# Processing Record 5 of Set 14 | ushuaia
# Processing Record 6 of Set 14 | bredasdorp
# Processing Record 7 of Set 14 | chalakudi
# Processing Record 8 of Set 14 | tupik
# Processing Record 9 of Set 14 | nikolskoye
# Processing Record 10 of Set 14 | hamilton
# Processing Record 11 of Set 14 | nuuk
# Processing Record 12 of Set 14 | barrow
# Processing Record 13 of Set 14 | richards bay
# Processing Record 14 of Set 14 | omsukchan
# Processing Record 15 of Set 14 | airai
# Processing Record 16 of Set 14 | bengkulu
# Processing Record 17 of Set 14 | yagodnoye
# Processing Record 18 of Set 14 | codrington
# Processing Record 19 of Set 14 | jamestown
# Processing Record 20 of Set 14 | port blair
# Processing Record 21 of Set 14 | mount gambier
# Processing Record 22 of Set 14 | kattivakkam
# Processing Record 23 of Set 14 | dikson
# Processing Record 24 of Set 14 | shimoda
# Processing Record 25 of Set 14 | nadym
# Processing Record 26 of Set 14 | hilo
# Processing Record 27 of Set 14 | kawalu
# Processing Record 28 of Set 14 | whitehorse
# Processing Record 29 of Set 14 | oranjemund
# Processing Record 30 of Set 14 | kodiak
# Processing Record 31 of Set 14 | hermanus
# Processing Record 32 of Set 14 | rawson
# Processing Record 33 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 14 | makakilo city
# Processing Record 35 of Set 14 | torbay
# Processing Record 36 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 14 | kapaa
# Processing Record 38 of Set 14 | tateyama
# Processing Record 39 of Set 14 | listvyagi
# Processing Record 40 of Set 14 | benghazi
# Processing Record 41 of Set 14 | jorochito
# Processing Record 42 of Set 14 | jaten
# Processing Record 43 of Set 14 | ponta do sol
# Processing Record 44 of Set 14 | ancud
# Processing Record 45 of Set 14 | half moon bay
# Processing Record 46 of Set 14 | carnarvon
# Processing Record 47 of Set 14 | acin
# City not found. Skipping...
# Processing Record 48 of Set 14 | palmas bellas
# Processing Record 49 of Set 14 | aras
# Processing Record 50 of Set 14 | nacozari
# Processing Record 1 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 2 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 15 | coahuayana
# Processing Record 4 of Set 15 | san quintin
# Processing Record 5 of Set 15 | mandalgovi
# Processing Record 6 of Set 15 | mamakan
# Processing Record 7 of Set 15 | tiksi
# Processing Record 8 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 15 | passo fundo
# Processing Record 10 of Set 15 | poum
# Processing Record 11 of Set 15 | karaton
# Processing Record 12 of Set 15 | tual
# Processing Record 13 of Set 15 | zhigansk
# Processing Record 14 of Set 15 | constitucion
# Processing Record 15 of Set 15 | lagoa
# Processing Record 16 of Set 15 | ahipara
# Processing Record 17 of Set 15 | narsaq
# Processing Record 18 of Set 15 | sandnessjoen
# Processing Record 19 of Set 15 | khovu-aksy
# Processing Record 20 of Set 15 | teguise
# Processing Record 21 of Set 15 | high level
# Processing Record 22 of Set 15 | maniitsoq
# Processing Record 23 of Set 15 | manzanillo
# Processing Record 24 of Set 15 | villa del rosario
# Processing Record 25 of Set 15 | zhangye
# Processing Record 26 of Set 15 | port hardy
# Processing Record 27 of Set 15 | hithadhoo
# Processing Record 28 of Set 15 | aklavik
# Processing Record 29 of Set 15 | ngunguru
# Processing Record 30 of Set 15 | pevek
# Processing Record 31 of Set 15 | saint george
# Processing Record 32 of Set 15 | zaozerne
# Processing Record 33 of Set 15 | mizan teferi
# Processing Record 34 of Set 15 | codajas
# Processing Record 35 of Set 15 | bluff
# Processing Record 36 of Set 15 | yerbogachen
# Processing Record 37 of Set 15 | porto belo
# Processing Record 38 of Set 15 | pisco
# Processing Record 39 of Set 15 | tomatlan
# Processing Record 40 of Set 15 | ambilobe
# Processing Record 41 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 15 | merauke
# Processing Record 43 of Set 15 | ribeira grande
# Processing Record 44 of Set 15 | kahului
# Processing Record 45 of Set 15 | fortuna
# Processing Record 46 of Set 15 | verkh-usugli
# Processing Record 47 of Set 15 | lijesnica
# Processing Record 48 of Set 15 | vila velha
# Processing Record 49 of Set 15 | oga
# Processing Record 50 of Set 15 | butaritari
# Processing Record 1 of Set 16 | vulcan
# Processing Record 2 of Set 16 | fillan
# Processing Record 3 of Set 16 | longyearbyen
# Processing Record 4 of Set 16 | bethel
# Processing Record 5 of Set 16 | jumla
# Processing Record 6 of Set 16 | berlevag
# Processing Record 7 of Set 16 | mar del plata
# Processing Record 8 of Set 16 | maneadero
# Processing Record 9 of Set 16 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 10 of Set 16 | severo-kurilsk
# Processing Record 11 of Set 16 | antofagasta
# Processing Record 12 of Set 16 | adrar
# Processing Record 13 of Set 16 | yellowknife
# Processing Record 14 of Set 16 | cidreira
# Processing Record 15 of Set 16 | bourail
# Processing Record 16 of Set 16 | correntina
# Processing Record 17 of Set 16 | puerto ayora
# Processing Record 18 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 16 | georgetown
# Processing Record 20 of Set 16 | north bend
# Processing Record 21 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 16 | yar-sale
# Processing Record 23 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 16 | vestmannaeyjar
# Processing Record 25 of Set 16 | lhokseumawe
# Processing Record 26 of Set 16 | luderitz
# Processing Record 27 of Set 16 | bennettsville
# Processing Record 28 of Set 16 | katsuura
# Processing Record 29 of Set 16 | kirovskiy
# Processing Record 30 of Set 16 | westport
# Processing Record 31 of Set 16 | te anau
# Processing Record 32 of Set 16 | chuy
# Processing Record 33 of Set 16 | lusaka
# Processing Record 34 of Set 16 | colares
# Processing Record 35 of Set 16 | gizo
# Processing Record 36 of Set 16 | walvis bay
# Processing Record 37 of Set 16 | belaya gora
# Processing Record 38 of Set 16 | nioro
# Processing Record 39 of Set 16 | petropavlovka
# Processing Record 40 of Set 16 | gilgit
# Processing Record 41 of Set 16 | serebryansk
# Processing Record 42 of Set 16 | east london
# Processing Record 43 of Set 16 | erzin
# Processing Record 44 of Set 16 | mezhdurechensk
# Processing Record 45 of Set 16 | jinxiang
# Processing Record 46 of Set 16 | vila franca do campo
# Processing Record 47 of Set 16 | gat
# Processing Record 48 of Set 16 | pimenta bueno
# Processing Record 49 of Set 16 | nago
# Processing Record 50 of Set 16 | palana
# Processing Record 1 of Set 17 | brae
# Processing Record 2 of Set 17 | cabedelo
# Processing Record 3 of Set 17 | lowestoft
# Processing Record 4 of Set 17 | saint-augustin
# Processing Record 5 of Set 17 | asfi
# Processing Record 6 of Set 17 | fort smith
# Processing Record 7 of Set 17 | itupiranga
# Processing Record 8 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 17 | tambul
# City not found. Skipping...
# Processing Record 10 of Set 17 | siguiri
# Processing Record 11 of Set 17 | norman wells
# Processing Record 12 of Set 17 | skibbereen
# Processing Record 13 of Set 17 | henties bay
# Processing Record 14 of Set 17 | isangel
# Processing Record 15 of Set 17 | tanete
# Processing Record 16 of Set 17 | timaru
# Processing Record 17 of Set 17 | hofn
# Processing Record 18 of Set 17 | campbell river
# Processing Record 19 of Set 17 | yankton
# Processing Record 20 of Set 17 | cordoba
# Processing Record 21 of Set 17 | toora-khem
# Processing Record 22 of Set 17 | udachnyy
# Processing Record 23 of Set 17 | meadow lake
# Processing Record 24 of Set 17 | klaksvik
# Processing Record 25 of Set 17 | pangnirtung
# Processing Record 26 of Set 17 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 17 | gerede
# Processing Record 28 of Set 17 | lincoln
# Processing Record 29 of Set 17 | bilibino
# Processing Record 30 of Set 17 | bosaso
# Processing Record 31 of Set 17 | praia
# Processing Record 32 of Set 17 | prince rupert
# Processing Record 33 of Set 17 | oriximina
# Processing Record 34 of Set 17 | islamkot
# Processing Record 35 of Set 17 | caravelas
# Processing Record 36 of Set 17 | cayenne
# Processing Record 37 of Set 17 | beloha
# Processing Record 38 of Set 17 | cherskiy
# Processing Record 39 of Set 17 | baturite
# Processing Record 40 of Set 17 | zaragoza
# Processing Record 41 of Set 17 | upernavik
# Processing Record 42 of Set 17 | afonso bezerra
# Processing Record 43 of Set 17 | sokoni
# Processing Record 44 of Set 17 | novopokrovka
# Processing Record 45 of Set 17 | mahebourg
# Processing Record 46 of Set 17 | vardo
# Processing Record 47 of Set 17 | raudeberg
# Processing Record 48 of Set 17 | sinjar
# Processing Record 49 of Set 17 | port hedland
# Processing Record 50 of Set 17 | esperance
# Processing Record 1 of Set 18 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 18 | hami
# Processing Record 3 of Set 18 | pucallpa
# Processing Record 4 of Set 18 | sur
# Processing Record 5 of Set 18 | faanui
# Processing Record 6 of Set 18 | taltal
# Processing Record 7 of Set 18 | xining
# Processing Record 8 of Set 18 | luena
# Processing Record 9 of Set 18 | san patricio
# Processing Record 10 of Set 18 | biu
# Processing Record 11 of Set 18 | jadu
# Processing Record 12 of Set 18 | quatre cocos
# Processing Record 13 of Set 18 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 18 | port-gentil
# Processing Record 15 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 18 | woodward
# Processing Record 17 of Set 18 | sindor
# Processing Record 18 of Set 18 | roald
# Processing Record 19 of Set 18 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 18 | xilagani
# Processing Record 21 of Set 18 | ahome
# Processing Record 22 of Set 18 | tabriz
# Processing Record 23 of Set 18 | avera
# Processing Record 24 of Set 18 | nishihara
# Processing Record 25 of Set 18 | gawler
# Processing Record 26 of Set 18 | mildura
# Processing Record 27 of Set 18 | birao
# Processing Record 28 of Set 18 | nanakuli
# Processing Record 29 of Set 18 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 18 | barroualie
# City not found. Skipping...
# Processing Record 31 of Set 18 | kokkola
# Processing Record 32 of Set 18 | jibuti
# Processing Record 33 of Set 18 | oyama
# Processing Record 34 of Set 18 | victoria
# Processing Record 35 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 18 | barstow
# Processing Record 37 of Set 18 | godfrey
# Processing Record 38 of Set 18 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 18 | arman
# Processing Record 40 of Set 18 | weihai
# Processing Record 41 of Set 18 | nanortalik
# Processing Record 42 of Set 18 | ndele
# Processing Record 43 of Set 18 | saint-leu
# Processing Record 44 of Set 18 | atbasar
# Processing Record 45 of Set 18 | carlyle
# Processing Record 46 of Set 18 | leningradskiy
# Processing Record 47 of Set 18 | menongue
# Processing Record 48 of Set 18 | lorengau
# Processing Record 49 of Set 18 | mikepercs
# Processing Record 50 of Set 18 | firozpur
# Processing Record 1 of Set 19 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 19 | niquero
# Processing Record 3 of Set 19 | kimberley
# Processing Record 4 of Set 19 | sistranda
# Processing Record 5 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 19 | santa fe
# Processing Record 7 of Set 19 | itarema
# Processing Record 8 of Set 19 | te karaka
# Processing Record 9 of Set 19 | fort walton beach
# Processing Record 10 of Set 19 | wampusirpi
# City not found. Skipping...
# Processing Record 11 of Set 19 | hualmay
# Processing Record 12 of Set 19 | kuala lipis
# Processing Record 13 of Set 19 | cabo san lucas
# Processing Record 14 of Set 19 | mehamn
# Processing Record 15 of Set 19 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 19 | hakvik
# City not found. Skipping...
# Processing Record 17 of Set 19 | provideniya
# Processing Record 18 of Set 19 | acapulco
# Processing Record 19 of Set 19 | gorin
# Processing Record 20 of Set 19 | libertador general san martin
# Processing Record 21 of Set 19 | cervo
# Processing Record 22 of Set 19 | talnakh
# Processing Record 23 of Set 19 | parras
# City not found. Skipping...
# Processing Record 24 of Set 19 | souillac
# Processing Record 25 of Set 19 | lebu
# Processing Record 26 of Set 19 | iqaluit
# Processing Record 27 of Set 19 | pasir gudang
# Processing Record 28 of Set 19 | aksu
# Processing Record 29 of Set 19 | del rio
# Processing Record 30 of Set 19 | batticaloa
# Processing Record 31 of Set 19 | saquarema
# Processing Record 32 of Set 19 | saint-georges
# Processing Record 33 of Set 19 | qui nhon
# Processing Record 34 of Set 19 | chipinge
# Processing Record 35 of Set 19 | garowe
# Processing Record 36 of Set 19 | college
# Processing Record 37 of Set 19 | myitkyina
# Processing Record 38 of Set 19 | ginir
# Processing Record 39 of Set 19 | beihai
# Processing Record 40 of Set 19 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 19 | port lincoln
# Processing Record 42 of Set 19 | san francisco
# Processing Record 43 of Set 19 | devaprayag
# Processing Record 44 of Set 19 | ozark
# Processing Record 45 of Set 19 | fukue
# Processing Record 46 of Set 19 | miranorte
# City not found. Skipping...
# Processing Record 47 of Set 19 | sumter
# Processing Record 48 of Set 19 | bairiki
# Processing Record 49 of Set 19 | russell
# Processing Record 50 of Set 19 | la ronge
# Processing Record 1 of Set 20 | kirakira
# Processing Record 2 of Set 20 | hokitika
# Processing Record 3 of Set 20 | serebryanyy bor
# Processing Record 4 of Set 20 | kiunga
# Processing Record 5 of Set 20 | ponta delgada
# Processing Record 6 of Set 20 | dagua
# Processing Record 7 of Set 20 | batagay-alyta
# Processing Record 8 of Set 20 | sola
# Processing Record 9 of Set 20 | nyurba
# Processing Record 10 of Set 20 | kysyl-syr
# Processing Record 11 of Set 20 | levokumskoye
# Processing Record 12 of Set 20 | kazachinskoye
# Processing Record 13 of Set 20 | one hundred mile house
# City not found. Skipping...
# Processing Record 14 of Set 20 | waingapu
# Processing Record 15 of Set 20 | egvekinot
# Processing Record 16 of Set 20 | benguela
# Processing Record 17 of Set 20 | scarborough
# Processing Record 18 of Set 20 | matara
# Processing Record 19 of Set 20 | lompoc
# Processing Record 20 of Set 20 | gravdal
# Processing Record 21 of Set 20 | srednekolymsk
# Processing Record 22 of Set 20 | cuitlahuac
# Processing Record 23 of Set 20 | ribas do rio pardo
# Processing Record 24 of Set 20 | hobyo
# Processing Record 25 of Set 20 | jyvaskyla
# Processing Record 26 of Set 20 | okhotsk
# Processing Record 27 of Set 20 | sitka
# Processing Record 28 of Set 20 | la malbaie
# Processing Record 29 of Set 20 | bilma
# Processing Record 30 of Set 20 | gaoua
# Processing Record 31 of Set 20 | geraldton
# Processing Record 32 of Set 20 | cao bang
# Processing Record 33 of Set 20 | santiago del estero
# Processing Record 34 of Set 20 | bousse
# Processing Record 35 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 20 | mwanza
# Processing Record 37 of Set 20 | townsville
# Processing Record 38 of Set 20 | kruisfontein
# Processing Record 39 of Set 20 | swan hill
# Processing Record 40 of Set 20 | pacific grove
# Processing Record 41 of Set 20 | grand gaube
# Processing Record 42 of Set 20 | stepnyak
# Processing Record 43 of Set 20 | murmashi
# Processing Record 44 of Set 20 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 20 | vallenar
# Processing Record 46 of Set 20 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 20 | raton
# Processing Record 48 of Set 20 | rurrenabaque
# Processing Record 49 of Set 20 | dingle
# Processing Record 50 of Set 20 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 21 | kolaras
# Processing Record 2 of Set 21 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 21 | tura
# Processing Record 4 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 21 | anadyr
# Processing Record 6 of Set 21 | farafangana
# Processing Record 7 of Set 21 | harku
# Processing Record 8 of Set 21 | broken hill
# Processing Record 9 of Set 21 | jiayuguan
# Processing Record 10 of Set 21 | williston
# Processing Record 11 of Set 21 | sorong
# Processing Record 12 of Set 21 | krasnyy chikoy
# Processing Record 13 of Set 21 | labuhan
# Processing Record 14 of Set 21 | rincon
# Processing Record 15 of Set 21 | axim
# Processing Record 16 of Set 21 | saryg-sep
# Processing Record 17 of Set 21 | pawayan
# Processing Record 18 of Set 21 | luxor
# Processing Record 19 of Set 21 | cajabamba
# Processing Record 20 of Set 21 | ostrovnoy
# Processing Record 21 of Set 21 | dudinka
# Processing Record 22 of Set 21 | castro
# Processing Record 23 of Set 21 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 21 | rehoboth
# Processing Record 25 of Set 21 | nhulunbuy
# Processing Record 26 of Set 21 | asau
# Processing Record 27 of Set 21 | chake chake
# Processing Record 28 of Set 21 | rocha
# Processing Record 29 of Set 21 | siocon
# Processing Record 30 of Set 21 | manuk mangkaw
# Processing Record 31 of Set 21 | shumikha
# Processing Record 32 of Set 21 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 21 | myski
# Processing Record 34 of Set 21 | laguna
# Processing Record 35 of Set 21 | mailsi
# Processing Record 36 of Set 21 | barcelos
# Processing Record 37 of Set 21 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 21 | vao
# Processing Record 39 of Set 21 | monrovia
# Processing Record 40 of Set 21 | upington
# Processing Record 41 of Set 21 | sabha
# Processing Record 42 of Set 21 | petropavlivka
# Processing Record 43 of Set 21 | baruun-urt
# Processing Record 44 of Set 21 | gorontalo
# Processing Record 45 of Set 21 | sioux city
# Processing Record 46 of Set 21 | soyaux
# Processing Record 47 of Set 21 | creston
# Processing Record 48 of Set 21 | verkhnyaya inta
# Processing Record 49 of Set 21 | ardrishaig
# Processing Record 50 of Set 21 | novyy rogachik
# Processing Record 1 of Set 22 | zhiryatino
# Processing Record 2 of Set 22 | brooks
# Processing Record 3 of Set 22 | butembo
# Processing Record 4 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 22 | mayo
# Processing Record 6 of Set 22 | zhongshu
# Processing Record 7 of Set 22 | san juan
# Processing Record 8 of Set 22 | bathsheba
# Processing Record 9 of Set 22 | rio tercero
# Processing Record 10 of Set 22 | husavik
# Processing Record 11 of Set 22 | saint anthony
# Processing Record 12 of Set 22 | coquimbo
# Processing Record 13 of Set 22 | naze
# Processing Record 14 of Set 22 | hambantota
# Processing Record 15 of Set 22 | tooele
# Processing Record 16 of Set 22 | lata
# Processing Record 17 of Set 22 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 22 | lamu
# Processing Record 19 of Set 22 | sao filipe
# Processing Record 20 of Set 22 | itoman
# Processing Record 21 of Set 22 | senmonorom
# City not found. Skipping...
# Processing Record 22 of Set 22 | mogzon
# Processing Record 23 of Set 22 | felidhoo
# City not found. Skipping...
# Processing Record 24 of Set 22 | ilulissat
# Processing Record 25 of Set 22 | ler
# Processing Record 26 of Set 22 | port pirie
# Processing Record 27 of Set 22 | coos bay
# Processing Record 28 of Set 22 | takoradi
# Processing Record 29 of Set 22 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 22 | keelung
# Processing Record 31 of Set 22 | gaya
# Processing Record 32 of Set 22 | kununurra
# Processing Record 33 of Set 22 | sayyan
# Processing Record 34 of Set 22 | faya
# Processing Record 35 of Set 22 | mindelo
# Processing Record 36 of Set 22 | port elizabeth
# Processing Record 37 of Set 22 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 22 | sisimiut
# Processing Record 39 of Set 22 | brenes
# Processing Record 40 of Set 22 | camacha
# Processing Record 41 of Set 22 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 22 | sibolga
# Processing Record 43 of Set 22 | umm lajj
# Processing Record 44 of Set 22 | uyovu
# Processing Record 45 of Set 22 | emerald
# Processing Record 46 of Set 22 | bahia blanca
# Processing Record 47 of Set 22 | basar
# Processing Record 48 of Set 22 | prince george
# Processing Record 49 of Set 22 | toul
# Processing Record 50 of Set 22 | padang
# Processing Record 1 of Set 23 | palmerston
# Processing Record 2 of Set 23 | grindavik
# Processing Record 3 of Set 23 | shelburne
# Processing Record 4 of Set 23 | avarua
# Processing Record 5 of Set 23 | kuva
# City not found. Skipping...
# Processing Record 6 of Set 23 | gasa
# Processing Record 7 of Set 23 | bocaranga
# City not found. Skipping...
# Processing Record 8 of Set 23 | buala
# Processing Record 9 of Set 23 | plouzane
# Processing Record 10 of Set 23 | malino
# Processing Record 11 of Set 23 | olafsvik
# Processing Record 12 of Set 23 | sontra
# Processing Record 13 of Set 23 | iroquois falls
# Processing Record 14 of Set 23 | bealanana
# Processing Record 15 of Set 23 | moctezuma
# Processing Record 16 of Set 23 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 23 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 23 | rokytne
# Processing Record 19 of Set 23 | gambela
# Processing Record 20 of Set 23 | hadejia
# Processing Record 21 of Set 23 | terrace
# Processing Record 22 of Set 23 | muros
# Processing Record 23 of Set 23 | puerto narino
# Processing Record 24 of Set 23 | bubaque
# Processing Record 25 of Set 23 | zemetchino
# Processing Record 26 of Set 23 | hillsborough
# Processing Record 27 of Set 23 | portobelo
# Processing Record 28 of Set 23 | maceio
# Processing Record 29 of Set 23 | tucson
# Processing Record 30 of Set 23 | idanre
# Processing Record 31 of Set 23 | verkhnyachka
# Processing Record 32 of Set 23 | flin flon
# Processing Record 33 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 23 | jalu
# Processing Record 35 of Set 23 | zhoucheng
# Processing Record 36 of Set 23 | malayal
# Processing Record 37 of Set 23 | chimbote
# Processing Record 38 of Set 23 | lakatoro
# Processing Record 39 of Set 23 | carauari
# Processing Record 40 of Set 23 | puerto maldonado
# Processing Record 41 of Set 23 | itacoatiara
# Processing Record 42 of Set 23 | bemidji
# Processing Record 43 of Set 23 | bouna
# Processing Record 44 of Set 23 | point pedro
# Processing Record 45 of Set 23 | peqin
# Processing Record 46 of Set 23 | dobryatino
# Processing Record 47 of Set 23 | xacmaz
# Processing Record 48 of Set 23 | gold coast
# Processing Record 49 of Set 23 | buchanan
# Processing Record 50 of Set 23 | sigli
# Processing Record 1 of Set 24 | tigil
# Processing Record 2 of Set 24 | papara
# Processing Record 3 of Set 24 | puerto baquerizo moreno
# Processing Record 4 of Set 24 | yarada
# Processing Record 5 of Set 24 | cheney
# Processing Record 6 of Set 24 | nantong
# Processing Record 7 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 24 | kipushi
# Processing Record 9 of Set 24 | ballina
# Processing Record 10 of Set 24 | kalemie
# Processing Record 11 of Set 24 | ziro
# Processing Record 12 of Set 24 | takaungu
# Processing Record 13 of Set 24 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 24 | madang
# Processing Record 15 of Set 24 | brownwood
# Processing Record 16 of Set 24 | shingu
# Processing Record 17 of Set 24 | kieta
# Processing Record 18 of Set 24 | oistins
# Processing Record 19 of Set 24 | kotturu
# Processing Record 20 of Set 24 | bandrele
# Processing Record 21 of Set 24 | elko
# Processing Record 22 of Set 24 | havelock
# Processing Record 23 of Set 24 | flinders
# Processing Record 24 of Set 24 | vikulovo
# Processing Record 25 of Set 24 | delaware
# Processing Record 26 of Set 24 | nome
# Processing Record 27 of Set 24 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 24 | nizwa
# Processing Record 29 of Set 24 | raha
# Processing Record 30 of Set 24 | la ciotat
# Processing Record 31 of Set 24 | khilok
# Processing Record 32 of Set 24 | brandon
# Processing Record 33 of Set 24 | manono
# Processing Record 34 of Set 24 | liezen
# Processing Record 35 of Set 24 | creel
# Processing Record 36 of Set 24 | kapit
# Processing Record 37 of Set 24 | tefe
# Processing Record 38 of Set 24 | moose factory
# Processing Record 39 of Set 24 | noyabrsk
# Processing Record 40 of Set 24 | rio gallegos
# Processing Record 41 of Set 24 | price
# Processing Record 42 of Set 24 | dire
# Processing Record 43 of Set 24 | salalah
# Processing Record 44 of Set 24 | kirkwall
# Processing Record 45 of Set 24 | qaqortoq
# Processing Record 46 of Set 24 | sao joao da barra
# Processing Record 47 of Set 24 | kavieng
# Processing Record 48 of Set 24 | bambanglipuro
# Processing Record 49 of Set 24 | floha
# Processing Record 50 of Set 24 | rawah
# Processing Record 1 of Set 25 | aripuana
# Processing Record 2 of Set 25 | saryagash
# Processing Record 3 of Set 25 | opuwo
# Processing Record 4 of Set 25 | los llanos de aridane
# Processing Record 5 of Set 25 | pemberton
# Processing Record 6 of Set 25 | aginskoye
# Processing Record 7 of Set 25 | wanaka
# Processing Record 8 of Set 25 | massakory
# Processing Record 9 of Set 25 | san cristobal
# Processing Record 10 of Set 25 | jacareacanga
# Processing Record 11 of Set 25 | soyo
# Processing Record 12 of Set 25 | tingo maria
# Processing Record 13 of Set 25 | wilmington
# Processing Record 14 of Set 25 | laurel
# Processing Record 15 of Set 25 | siwani
# City not found. Skipping...
# Processing Record 16 of Set 25 | puerto morazan
# Processing Record 17 of Set 25 | kushmurun
# Processing Record 18 of Set 25 | keffi
# Processing Record 19 of Set 25 | moindou
# Processing Record 20 of Set 25 | nouadhibou
# Processing Record 21 of Set 25 | mumford
# Processing Record 22 of Set 25 | aykhal
# Processing Record 23 of Set 25 | harrison
# Processing Record 24 of Set 25 | tabou
# Processing Record 25 of Set 25 | pilar
# Processing Record 26 of Set 25 | mezen
# Processing Record 27 of Set 25 | bobon
# Processing Record 28 of Set 25 | aksay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     61.00        99          99
# 1           Atuona  -9.8000 -139.0333     80.60        77          18
# 2        Barbacoas   1.6715  -78.1398     77.72        93          99
# 3          Rikitea -23.1203 -134.9692     78.30        74           7
# 4            Vaini -21.2000 -175.2000     80.60        69          20
# 5          Qaanaaq  77.4840  -69.3632     23.05        94         100
# 6      Tuktoyaktuk  69.4541 -133.0374     -5.80        71           1
# 7            Kotka  60.4664   26.9458     39.00        65           0
# 8  Bambous Virieux -20.3428   57.7575     78.01        94          75
# 9  Haines Junction  60.7522 -137.5108     23.00        30          91
#
#    Wind Speed Country                 Date Current Description
# 0        1.01      AU  2021-04-11 22:31:19     overcast clouds
# 1       17.02      PF  2021-04-11 22:31:19          few clouds
# 2        2.33      CO  2021-04-11 22:31:19          light rain
# 3        8.19      PF  2021-04-11 22:28:26          light rain
# 4        5.75      TO  2021-04-11 22:31:20          few clouds
# 5        9.69      GL  2021-04-11 22:31:20                snow
# 6        9.22      CA  2021-04-11 22:31:21           clear sky
# 7        6.91      FI  2021-04-11 22:29:24           clear sky
# 8        6.91      MU  2021-04-11 22:31:21       broken clouds
# 9        4.61      CA  2021-04-11 22:31:21     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
